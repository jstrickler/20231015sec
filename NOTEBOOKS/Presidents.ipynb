# %%
# %pylab
# %matplotlib inline
import pandas as pd
import seaborn as sns
sns.set()
# Out:
# Using matplotlib backend: <object object at 0x110a7b520>
# %pylab is deprecated, use %matplotlib inline and import the required libraries.
# Populating the interactive namespace from numpy and matplotlib

# %%
df = pd.read_excel('http://qrc.depaul.edu/Excel_Files/Presidents.xlsx', sheet_name='Master',
                  na_values='NA()')
df.index = range(1,len(df)+1)
df
# Out:
#     No               President  Years in office  Year first inaugurated  \
# 1    1       George Washington              8.0                    1789
# 2    2              John Adams              4.0                    1797
# 3    3        Thomas Jefferson              8.0                    1801
# 4    4           James Madison              8.0                    1809
# 5    5            James Monroe              8.0                    1817
# 6    6       John Quincy Adams              4.0                    1825
# 7    7          Andrew Jackson              8.0                    1829
# 8    8       Martin Van Buren               4.0                    1837
# 9    9  William Henry Harrison              0.8                    1841
# 10  10              John Tyler              4.0                    1841
# 11  11           James K. Polk              4.0                    1845
# 12  12          Zachary Taylor              1.0                    1849
# 13  13        Millard Fillmore              3.0                    1850
# 14  14         Franklin Pierce              4.0                    1853
# 15  15          James Buchanan              4.0                    1857
# 16  16         Abraham Lincoln              4.0                    1861
# 17  17          Andrew Johnson              4.0                    1865
# 18  18        Ulysses S. Grant              8.0                    1869
# 19  19     Rutherford B. Hayes              4.0                    1877
# 20  20       James A. Garfield              0.5                    1881
# 21  21       Chester A. Arthur              3.0                    1881
# 22  22        Grover Cleveland              4.0                    1885
# 23  23       Benjamin Harrison              4.0                    1889
# 24  24        Grover Cleveland              4.0                    1893
# 25  25        William McKinley              4.0                    1897
# 26  26      Theodore Roosevelt              8.0                    1901
# 27  27     William Howard Taft              4.0                    1909
# 28  28          Woodrow Wilson              8.0                    1913
# 29  29       Warren G. Harding              2.0                    1921
# 30  30         Calvin Coolidge              6.0                    1923
# 31  31          Herbert Hoover              4.0                    1929
# 32  32      Franklin Roosevelt             12.0                    1933
# 33  33         Harry S. Truman              8.0                    1945
# 34  34    Dwight D. Eisenhower              8.0                    1953
# 35  35         John F. Kennedy              3.0                    1961
# 36  36       Lyndon B. Johnson              5.0                    1963
# 37  37        Richard M. Nixon              5.0                    1969
# 38  38             Gerald Ford              3.0                    1974
# 39  39            Jimmy Carter              4.0                    1977
# 40  40           Ronald Reagan              8.0                    1981
# 41  41             George Bush              4.0                    1989
# 42  42            Bill Clinton              8.0                    1993
# 43  43          George W. Bush              8.0                    2001
# 44  44            Barack Obama              8.0                    2009
# 45  45         Donald J. Trump              4.0                    2017
# 46  46            Joseph Biden              1.0                    2021
#
#     Age at inauguration State elected from  # of electoral votes  \
# 1                    57           Virginia                  69.0
# 2                    61      Massachusetts                 132.0
# 3                    57           Virginia                  73.0
# 4                    57           Virginia                 122.0
# 5                    58           Virginia                 183.0
# 6                    57      Massachusetts                  84.0
# 7                    61          Tennessee                 178.0
# 8                    54           New York                 170.0
# 9                    68               Ohio                 234.0
# 10                   51           Virginia                   NaN
# 11                   49          Tennessee                 170.0
# 12                   64          Louisiana                 163.0
# 13                   50           New York                   NaN
# 14                   48      New Hampshire                 254.0
# 15                   65       Pennsylvania                 174.0
# 16                   52           Illinois                 180.0
# 17                   56          Tennessee                   NaN
# 18                   46           Illinois                 214.0
# 19                   54               Ohio                 185.0
# 20                   49               Ohio                 214.0
# 21                   50           New York                   NaN
# 22                   47           New York                 219.0
# 23                   55            Indiana                 233.0
# 13          395.0                   Whig           Lawyer
# 14          286.0               Democrat           Lawyer
# 15          259.0               Democrat           Lawyer
# 16          900.0             Republican           Lawyer
# 17          280.0         National Union           Tailor
# 18          403.0             Republican          Soldier
# 19          477.0             Republican           Lawyer
# 20          444.0             Republican           Lawyer
# 21          423.0             Republican           Lawyer
# 22          576.0               Democrat           Lawyer
# 23          426.0             Republican           Lawyer
# 24          576.0               Democrat           Lawyer
# 25          601.0             Republican           Lawyer
# 26          810.0             Republican           Author
# 27          491.0             Republican           Lawyer
# 28          723.0               Democrat         Educator
# 29          326.0             Republican           Editor
# 30          451.0             Republican           Lawyer
# 31          400.0             Republican         Engineer
# 32          876.0               Democrat           Lawyer
# 33          753.0               Democrat      Businessman
# 34          699.0             Republican          Soldier
# 35          704.0               Democrat           Author
# 36          655.0               Democrat          Teacher
# 37          477.0             Republican           Lawyer
# 38          495.0             Republican           Lawyer
# 39          518.0               Democrat      Businessman
# 40          634.0             Republican            Actor
# 41          548.0             Republican      Businessman
# 42          539.0               Democrat           Lawyer
# 43            NaN             Republican      Businessman
# 44            NaN               Democrat           Lawyer
# 45            NaN             Republican      Businessman
# 46            NaN               Democrat           Lawyer
#
#                                              College  % electoral  % popular
# 1                                                NaN   100.000000        NaN
# 2                                            Harvard    94.964029        NaN
# 3                                   William and Mary    53.284672        NaN
# 4                                          Princeton    69.318182        NaN
# 5                                   William and Mary    82.805430        NaN
# 6                                            Harvard    32.183908        NaN
# 7                                                NaN    68.199234  55.970638
# 8                                                NaN    57.823129  50.825322
# 9                                     Hampden-Sydney    79.591837  52.881075
# 10                                  William and Mary          NaN        NaN
# 11                              U. of North Carolina    61.818182  49.543748
# 12                                               NaN    56.206897  47.283987
# 13                                               NaN          NaN        NaN
# 14                                           Bowdoin    85.810811  50.841127
# 15                                         Dickinson    58.783784  45.283153
# 16                                               NaN    59.405941  39.822510
# 17                                               NaN          NaN        NaN
# 18                               US Military Academy    72.789116  52.663724
# 19                                            Kenyon    50.135501  47.952723
# 20                                          Williams    57.994580  48.273130
# 21                                             Union          NaN        NaN
# 22                                               NaN    54.613466  48.504879
# 23                                             Miami    58.104738  47.823412
# 24                                               NaN    62.387387  46.050417
# 25                                 Allegheny College    60.626398  51.008996
# 26                                           Harvard          NaN        NaN
# 27                                              Yale    66.459627  51.578279
# 28                                         Princeton    81.920904  41.840087
# 29                                               NaN    76.082863  60.302919
# 30                                           Amherst          NaN        NaN
# 31                                          Stanford    83.615819  58.199998
# 32                                           Harvard    88.888889  57.422317
# 33                                               NaN          NaN        NaN
# 34                               US Military Academy    83.239171  55.134883
# 35                                           Harvard    56.424581  49.719397
# 36                             Southwest Texas State          NaN        NaN
# 37                                          Whittier    55.947955  43.420334
# 38                                          Michigan          NaN        NaN
# 39                                  US Naval Academy    55.204461  50.064764
# 40                                    Eureka College    90.892193  50.747316
# 41                                              Yale    79.182156  53.377947
# 42                                        Georgetown    68.773234  43.006292
# 43                                              Yale    50.371747  47.867030
# 44                               Columbia University    67.843866  53.687457
# 45  Wharton School of the University of Pennsylvania    56.505576  46.095524
# 46                            University of Delaware    56.877323  51.313678

# %%
# %matplotlib inline
parties = df['Political Party'].value_counts()
parties
# Out:
# Political Party
# Republican               19
# Democrat                 16
# Democratic-Republican     4
# Whig                      4
# Federalist                1
# National Union            1
# Name: count, dtype: int64

# %%
parties.plot(kind="bar")
# Out:
# <Axes: xlabel='Political Party'>

# %%
occupations = df['Occupation'].value_counts()
occupations
# Out:
# Occupation
# Lawyer             27
# Businessman         5
# Soldier             4
# Author              2
# Planter             1
# Planter, Lawyer     1
# Tailor              1
# Educator            1
# Editor              1
# Engineer            1
# Teacher             1
# Actor               1
# Name: count, dtype: int64

# %%
occupations.plot(kind="pie")
# Out:
# <Axes: ylabel='count'>

# %%
plt.hlines?
# Out:
# Signature:
# plt.hlines(
#     y,
#     xmin,
#     xmax,
#     colors=None,
#     linestyles='solid',
#     label='',
#     *,
#     data=None,
#     **kwargs,
# )
# Docstring:
# Plot horizontal lines at each *y* from *xmin* to *xmax*.
#
# Parameters
# ----------
# y : float or array-like
#     y-indexes where to plot the lines.
#
# xmin, xmax : float or array-like
#     Respective beginning and end of each line. If scalars are
#     provided, all lines will have the same length.
#
# colors : list of colors, default: :rc:`lines.color`
#
# linestyles : {'solid', 'dashed', 'dashdot', 'dotted'}, optional
#
# label : str, default: ''
#
# Returns
# -------
# `~matplotlib.collections.LineCollection`
#
# Other Parameters
# ----------------
# data : indexable object, optional
#     If given, the following parameters also accept a string ``s``, which is
#     interpreted as ``data[s]`` (unless this raises an exception):
#
#     *y*, *xmin*, *xmax*, *colors*
# **kwargs :  `~matplotlib.collections.LineCollection` properties.
#
# See Also
# --------
# vlines : vertical lines
# axhline : horizontal line across the Axes
# File:      ~/anaconda3/lib/python3.11/site-packages/matplotlib/pyplot.py
# Type:      function

# %%
plt.bar(df['Year first inaugurated'].values, df['% popular'].values)
plt.title("Popular Vote in US Presidential Elections")
plt.xlabel("Year Inaugurated")
plt.ylabel("% Of Popular Vote")
# Out:
# Text(0, 0.5, '% Of Popular Vote')

# %%
gb = df[['State elected from', 'Age at inauguration']].groupby('State elected from').agg("max").sort_values(by="Age at inauguration").reset_index()
gb
# Out:
#    State elected from  Age at inauguration
# 0            Arkansas                   46
# 1       New Hampshire                   48
# 2             Georgia                   52
# 3            Illinois                   52
# 4             Indiana                   55
# 5          New Jersey                   56
# 6            Virginia                   58
# 7            Missouri                   60
# 8       Massachusetts                   61
# 9           Tennessee                   61
# 10           Michigan                   61
# 11              Texas                   64
# 12          Louisiana                   64
# 13       Pennsylvania                   65
# 14               Ohio                   68
# 15         California                   69
# 16           New York                   70
# 17           Delaware                   78

# %%
pt = df.pivot_table(index='State elected from', values="Age at inauguration", aggfunc="max").sort_values(by="Age at inauguration").reset_index()
pt
# Out:
#    State elected from  Age at inauguration
# 0            Arkansas                   46
# 1       New Hampshire                   48
# 2             Georgia                   52
# 3            Illinois                   52
# 4             Indiana                   55
# 5          New Jersey                   56
# 6            Virginia                   58
# 7            Missouri                   60
# 8       Massachusetts                   61
# 9           Tennessee                   61
# 10           Michigan                   61
# 11              Texas                   64
# 12          Louisiana                   64
# 13       Pennsylvania                   65
# 14               Ohio                   68
# 15         California                   69
# 16           New York                   70
# 17           Delaware                   78

# %%
gb.equals(pt)
# Out:
# True

# %%
sns.barplot(data=gb, x='Age at inauguration',  y='State elected from', orient='h')
# Out:
# <Axes: xlabel='Age at inauguration', ylabel='State elected from'>
